# %%
#file handling

# %%
#lst=open(r'C:\Users\Administrator\Desktop\sample.txt','r')
#lst.close()

# %%
import os
lst=open('/Users/Administrator/Desktop/hii/sample.txt',"r")
lst.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 lst=open('/Users/Administrator/Desktop/hii/sample.txt')
#       3 lst.close()
#
# File C:\Program Files\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Administrator/Desktop/hii/sample.txt'

# %%
import os
p=os.getenv("Home")
print(p)
# Out:
# None

# %%
import os
os.getenv("Users/Administrator")
lst=open("ym.txt","w")
lst.write("this is 1st module\n")
lst.write("this is 2st module\n")
lst.close()

# %%
lst=open("ym.txt","r")
lst.read()
# Out:
# 'this is 1st module\nthis is 2st module\n'

# %%
lst=open("ym.txt","r")
lst.read(4)
# Out:
# 'this'

# %%
lst.tell()
# Out:
# 4

# %%
lst.seek(5)#it will set  again pointer position
# Out:
# 5

# %%
print(lst.read())
# Out:
# is 1st module
# this is 2st module

# %%
lst.tell()
# Out:
# 40

# %%
lst.read()
# Out:
# ''

# %%
lst.tell()
# Out:
# 40

# %%
lst.seek(5)
print(lst.read())
# Out:
# is 1st module
# this is 2st module

# %%
lst.seek(0)
for i in lst:
    print(i)
# Out:
# this is 1st module
#
# this is 2st module

# %%
lst = open("ym.txt","r")
lst.readline()
# Out:
# 'this is 1st module\n'

# %%
lst.readline()
# Out:
# 'this is 2st module\n'

# %%
lst.readline()
# Out:
# ''

# %%
lst = open("ym.txt","r")
lst.readlines() #read the entire file
# Out:
# ['this is 1st module\n', 'this is 2st module\n']

# %%
lst.close()

# %%
import os
os .rename("ym.txt","sample.txt")

# %%
lst=open("sample.txt","r")
lst.readlines()
# Out:
# ['this is 1st module\n', 'this is 2st module\n']

# %%
os.remove("text.txt")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("/Users/Administrator/Desktop/hii")#change the directory

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'.ipython',
#  b'.jupyter',
#  b'.scala_history',
#  b'.scala_history_jline3',
#  b'3D Objects',
#  b'AppData',
#  b'Application Data',
#  b'assignment.txt',
#  b'Contacts',
#  b'Cookies',
#  b'day1.ipynb',
#  b'day1_assignment.ipynb',
#  b'day2.ipynb',
#  b'day2_assignment.ipynb',
#  b'Desktop',
#  b'Documents',
#  b'Downloads',
#  b'Favorites',
#  b'Links',
#  b'Local Settings',
#  b'Music',
#  b'My Documents',
#  b'NetHood',
#  b'NTUSER.DAT',
#  b'ntuser.dat.LOG1',
#  b'ntuser.dat.LOG2',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  b'ntuser.ini',
#  b'OneDrive',
#  b'Pictures',
#  b'PrintHood',
#  b'Recent',
#  b'sample.txt',
#  b'Saved Games',
#  b'Searches',
#  b'SendTo',
#  b'Start Menu',
#  b'Templates',
#  b'Untitled.ipynb',
# ...

# %%
os.mkdir("anvin")

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.scala_history',
#  '.scala_history_jline3',
#  '3D Objects',
#  'anvin',
#  'AppData',
#  'Application Data',
#  'assignment.txt',
#  'Contacts',
#  'Cookies',
#  'day1.ipynb',
#  'day1_assignment.ipynb',
#  'day2.ipynb',
#  'day2_assignment.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'sample.txt',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'untitled.txt',
# ...

# %%
import shutil
shutil.rmtree('/Users/Administrator/assignment1') #removed the folder with file

# %%
#modules and packages

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
import datetime as d
print(d.datetime.now())
# Out:
# 2026-02-20 11:32:15.950624
